# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.animation as an
from IPython.display import display, HTML

# %%
# animation class
class animate_imshow():
    def __init__(self, arrays, dt=1, t0=1):
        """
        Array is a list of 2d arrays or a 3d array with time on axis=0.
        Note in jupyter the animation needs to be done"
        """ 
        # setup data
        self.arr = arrays
        self.Nt = len(arrays)
        self.dt = dt
        self.t0 = t0

        # setup the figure
        self.fig = plt.figure(figsize=(6, 6))
        self.im = plt.imshow(arrays[0], animated=True, cmap='viridis')
        self.ax = plt.gca()
        self.text = self.ax.text(0.1, 0.1, 'Time: ' + str(t0), color='w')
        
        # settings
        self.delay = 10
        self.title = "title"
        self.xlabel = "xlabel"
        self.ylabel = "ylabel"

        # run the animation
    def run(self, html = False):
        self.ax.set(title=self.title, xlabel=self.xlabel, ylabel=self.ylabel)
        self.ani = an.FuncAnimation(self.fig, self.update, frames=range(self.Nt),
                                    interval=self.delay, blit=True)
        
        if html: # use this if in ipython/jupyter notebooks
            plt.close(self.fig)
            self.jshtml = self.ani.to_jshtml()
            display(HTML(self.jshtml))
    
    def save_html(self, filename = "output.html"):
        if not hasattr(self, 'jshtml'):
            self.jshtml = self.ani.to_jshtml()
        f = open(filename, 'w')
        f.write(self.jshtml)
        f.close()
            
    def update(self, f):
        self.im.set_array(self.arr[f])
        time = int(f * self.dt + self.t0)
        self.text.set_text('Time: %i' % time)
        return self.im, self.text

# %%
# what to load
#directory = "/Users/Richard/OneDrive\ -\ Imperial\ College\ London/_ACSE-6/project_3/vs_gol/Debug/test_no_send/"
directory = "../vs_gol/Debug/test_no_send/"
node = 0
iter_start = 0
iter_end = 10

# %%
# check directory is real
assert os.path.isdir(directory), "Given directory does not exist"

# generate all file names
files = [directory + str(i) + "-" + str(node) + ".csv" for i in range(iter_start, iter_end + 1)]
display(files)

# check all files exist
assert all([os.path.isfile(f) for f in files]), "One or more iteration files does not exist"
# Out:
# ['../vs_gol/Debug/test_no_send/0-1.csv',
#  '../vs_gol/Debug/test_no_send/1-1.csv',
#  '../vs_gol/Debug/test_no_send/2-1.csv',
#  '../vs_gol/Debug/test_no_send/3-1.csv',
#  '../vs_gol/Debug/test_no_send/4-1.csv',
#  '../vs_gol/Debug/test_no_send/5-1.csv',
#  '../vs_gol/Debug/test_no_send/6-1.csv',
#  '../vs_gol/Debug/test_no_send/7-1.csv',
#  '../vs_gol/Debug/test_no_send/8-1.csv',
#  '../vs_gol/Debug/test_no_send/9-1.csv',
#  '../vs_gol/Debug/test_no_send/10-1.csv']

# %%
# load the data and check the dimensions match
results = [np.loadtxt(f, dtype=int, delimiter=',') for f in files]
display([r.shape for r in results])
assert all([results[0].shape == r.shape for r in results]), "Save files have incorrect dimensions"
display(results)
# Out:
# [(40, 20),
#  (40, 20),
#  (40, 20),
#  (40, 20),
#  (40, 20),
#  (40, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20)]
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-75-bccf851bcbbd> in <module>()
#       2 results = [np.loadtxt(f, dtype=int, delimiter=',') for f in files]
#       3 display([r.shape for r in results])
# ----> 4 assert all([results[0].shape == r.shape for r in results]), "Save files have incorrect dimensions"
#       5 display(results)
#
# AssertionError: Save files have incorrect dimensions

# %%
gol_ani = animate_imshow(results, 1, iter_start)
gol_ani.delay = 100
gol_ani.run(html=True)
#gol_ani.save(directory + node + "-" + iter_start + "-" iter_end + ".html")
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_img85a305cae5af42f0a7344bf57764a357">
#     <br>
#     <input id="_anim_slider85a305cae5af42f0a7344bf57764a357" type="range" style="width:350px"
#            name="points" min="0" max="1" step="1" value="0"
#            onchange="anim85a305cae5af42f0a7344bf57764a357.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="anim85a305cae5af42f0a7344bf57764a357.slower()"><i class="fa fa-minus"></i></button>
#     <button onclick="anim85a305cae5af42f0a7344bf57764a357.first_frame()"><i class="fa fa-fast-backward">
#         </i></button>
#     <button onclick="anim85a305cae5af42f0a7344bf57764a357.previous_frame()">
#         <i class="fa fa-step-backward"></i></button>
#     <button onclick="anim85a305cae5af42f0a7344bf57764a357.reverse_animation()">
#         <i class="fa fa-play fa-flip-horizontal"></i></button>
#     <button onclick="anim85a305cae5af42f0a7344bf57764a357.pause_animation()"><i class="fa fa-pause">
#         </i></button>
#     <button onclick="anim85a305cae5af42f0a7344bf57764a357.play_animation()"><i class="fa fa-play"></i>
#         </button>
#     <button onclick="anim85a305cae5af42f0a7344bf57764a357.next_frame()"><i class="fa fa-step-forward">
#         </i></button>
#     <button onclick="anim85a305cae5af42f0a7344bf57764a357.last_frame()"><i class="fa fa-fast-forward">
#         </i></button>
#     <button onclick="anim85a305cae5af42f0a7344bf57764a357.faster()"><i class="fa fa-plus"></i></button>
#   <form action="#n" name="_anim_loop_select85a305cae5af42f0a7344bf57764a357" class="anim_control">
#     <input type="radio" name="state"
#            value="once" > Once </input>
#     <input type="radio" name="state"
#            value="loop" checked> Loop </input>
#     <input type="radio" name="state"
#            value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img85a305cae5af42f0a7344bf57764a357";
#     var slider_id = "_anim_slider85a305cae5af42f0a7344bf57764a357";
#     var loop_select_id = "_anim_loop_select85a305cae5af42f0a7344bf57764a357";
#     var frames = new Array(0);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADl0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uIDIuMi4yLCBo\
# dHRwOi8vbWF0cGxvdGxpYi5vcmcvhp/UCwAAG/VJREFUeJzt3W90VIX95/HPTcIfa2AhP0wciBgR\
# 1BDAaTIxUJGGxgh1MZSiCNqeQJCsKNWDcIRWj8aWIrTbom66R6JsTe0utrgClqMRELEVhTiro6W0\
# GigIpFn+mCAEAwyTuw84nXOyBEiA5M6Xeb8eJbkzySd58ube+YPjuq4rAACMSfB6AAAA54OAAQBM\
# ImAAAJMIGADAJAIGADCJgAEATCJgAACTCBgAwCQCBgAwiYABAEwiYAAAkwgYAMAkAgYAMImAAQBM\
# ImAAAJMIGADAJAIGADCJgAEATCJgAACTCBgAwCQCBgAwiYABAEwiYAAAkwgYAMAkAgYAMImAAQBM\
# ImAAAJMIGADAJAIGADCJgAEATCJgAACTCBgAwCQCBgAwiYABAEwiYAAAkwgY0AF2796t5ORkRSKR\
# M97GcRxt3769E1cBlxYCBlwkGRkZWr9+vSSpf//+amxsVGJioiQpPz9fL774opfzgEsOAQMAmETA\
# gIvghz/8oXbv3q077rhDycnJ+sUvfiHHcXTy5Ek99thj+stf/qJZs2YpOTlZs2bNOu3+x48f19y5\
# c9W/f3+lpaXp/vvvV1NTkwe/CWAHAQMugpdffln9+/fXn/70JzU2NmrSpEnRYz//+c91yy23qLy8\
# XI2NjSovLz/t/vPmzdPnn3+uUCik7du3q7a2Vj/96U8781cAzCFggMdc19ULL7ygJUuWKCUlRT16\
# 9NBPfvITvfLKK15PA2JaktcDgHh34MABff3118rJyYl+zXXdsz6DEQABAy4ax3HO61ifPn102WWX\
# 6W9/+5v69evXEdOASxKXEIGLJC0tTf/85z/bfSwhIUEzZszQ7NmztX//fklSbW2t3nrrrQ7bClwK\
# CBhwkfz4xz/WggUL1KtXL7366qstjj388MN69dVX1bt3bz300EOn3Xfx4sUaOHCghg8frp49e+rW\
# W2/VZ5991lnTAZMc13Vdr0cAANBenIEBAEwiYAAAkwgYAMAkAgYAMImAAQBM4oXMca6qqkoPP/yw\
# IpGI7rvvPs2fP/+st+/qdFN3XX7G4z9+cp4aG4/qv/3q1Pv9/evIbvXt0V8jv32z/teq3ys3c7ga\
# 6hv06T8/0u9e/L0Wli3SzIf+i66+5mrNn/0TLfufFXrhvy/T5k1blH5VP618638rd/BwfTPHr5L7\
# p+lHMx5u8fPGTyzSrWMLol+f/INJCuTlaO6P5l3gXwax7piO6oR73OsZ8BABi2ORSEQPPvig1q1b\
# p/T0dOXm5qqoqEiDBw8+432663LlOQVnPN7PuUZNzrHobRKVpDynQJnOYO348Atl7BuiDEkHdxzS\
# /113WHlOgZq3dteNo7OV5xTo1lsLlT04EP1+/6lnT+X3+M9q+uiYfl/6+mk/+7qEoUp1+ka/fq2T\
# pVSln3UjLg1b3Le9ngCPEbA4Vl1drYEDB2rAgAGSpMmTJ2v16tVnDdiFCB8PRz92m93o583NzUpM\
# OvUfPyYkOHroW4/pxLETbfqeB/bW64r0/4h+3ic9RV/+q/4irgYQq3gMLI7V1tbqqquuin6enp6u\
# 2tpaDxdJ/2ftpxo/a2z082tvzDjr7T/7cLv6DfLpyoxUJXVJUv7dN+uD14MdvBJALCBgcay1N2Fp\
# 7U1nKyoqFAgEFAgEFFbHPubwm4f/h67LuVZLQ/9VL25donH3F0qSrssZoEdeuP+02zdHmlX+o2V6\
# uuoxLdu2RH9e8YG+2La3QzcCiA28lVQc++CDD1RWVhZ909inn35a0qn39DuTnk4Kjy8hJmxx39Zh\
# l8vF8YwzsDiWm5urmpoa7dy5UydOnNArr7yioqIir2cBQJvwJI44lpSUpPLyco0ZM
