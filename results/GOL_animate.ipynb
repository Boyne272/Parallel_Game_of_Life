# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.animation as an
from IPython.display import display, HTML

# %%
# animation class
class animate_imshow():
    def __init__(self, arrays, dt=1, t0=1):
        """
        Array is a list of 2d arrays or a 3d array with time on axis=0.
        Note in jupyter the animation needs to be done"
        """ 
        # setup data
        self.arr = arrays
        self.Nt = len(arrays)
        self.Nx = len(arrays[0])
        self.dt = dt
        self.t0 = t0

        # setup the figure
        self.fig = plt.figure(figsize=(6, 6))
        self.im = plt.imshow(arrays[0], animated=True, cmap='viridis')
        self.ax = plt.gca()
        self.text = self.ax.text(0.02*self.Nx, 0.04*self.Nx, 'Time: ' + str(t0), color='w')
        
        # settings
        self.delay = 10
        self.title = "title"
        self.xlabel = "xlabel"
        self.ylabel = "ylabel"

        # run the animation
    def run(self, html = False):
        self.ax.set(title=self.title, xlabel=self.xlabel, ylabel=self.ylabel)
        self.ani = an.FuncAnimation(self.fig, self.update, frames=range(self.Nt),
                                    interval=self.delay, blit=True)
        
        if html: # use this if in ipython/jupyter notebooks
            plt.close(self.fig)
            self.jshtml = self.ani.to_jshtml()
            display(HTML(self.jshtml))
    
    def save_html(self, filename = "output.html"):
        if not hasattr(self, 'jshtml'):
            self.jshtml = self.ani.to_jshtml()
        f = open(filename, 'w')
        f.write(self.jshtml)
        f.close()
            
    def update(self, f):
        self.im.set_array(self.arr[f])
        time = int(f * self.dt + self.t0)
        self.text.set_text('Time: %i' % time)
        return self.im, self.text

# %%
# what to load
directory = "../vs_gol/Debug/test_periodic/"
node = "all"
iter_start = 0
iter_end = 100

# check directory is real
assert os.path.isdir(directory), "Given directory does not exist"

# generate all file names
files = [directory + str(i) + "-" + str(node) + ".csv" for i in range(iter_start, iter_end + 1)]
display(files)

# check all files exist
assert all([os.path.isfile(f) for f in files]), "One or more iteration files does not exist"

# load the data and check the dimensions match
results = [np.loadtxt(f, dtype=int, delimiter=',') for f in files]
display([r.shape for r in results])
assert all([results[0].shape == r.shape for r in results]), "Save files have incorrect dimensions"
#display(results)
# Out:
# ['../vs_gol/Debug/test_periodic/0-all.csv',
#  '../vs_gol/Debug/test_periodic/1-all.csv',
#  '../vs_gol/Debug/test_periodic/2-all.csv',
#  '../vs_gol/Debug/test_periodic/3-all.csv',
#  '../vs_gol/Debug/test_periodic/4-all.csv',
#  '../vs_gol/Debug/test_periodic/5-all.csv',
#  '../vs_gol/Debug/test_periodic/6-all.csv',
#  '../vs_gol/Debug/test_periodic/7-all.csv',
#  '../vs_gol/Debug/test_periodic/8-all.csv',
#  '../vs_gol/Debug/test_periodic/9-all.csv',
#  '../vs_gol/Debug/test_periodic/10-all.csv',
#  '../vs_gol/Debug/test_periodic/11-all.csv',
#  '../vs_gol/Debug/test_periodic/12-all.csv',
#  '../vs_gol/Debug/test_periodic/13-all.csv',
#  '../vs_gol/Debug/test_periodic/14-all.csv',
#  '../vs_gol/Debug/test_periodic/15-all.csv',
#  '../vs_gol/Debug/test_periodic/16-all.csv',
#  '../vs_gol/Debug/test_periodic/17-all.csv',
#  '../vs_gol/Debug/test_periodic/18-all.csv',
#  '../vs_gol/Debug/test_periodic/19-all.csv',
#  '../vs_gol/Debug/test_periodic/20-all.csv',
#  '../vs_gol/Debug/test_periodic/21-all.csv',
#  '../vs_gol/Debug/test_periodic/22-all.csv',
#  '../vs_gol/Debug/test_periodic/23-all.csv',
#  '../vs_gol/Debug/test_periodic/24-all.csv',
#  '../vs_gol/Debug/test_periodic/25-all.csv',
#  '../vs_gol/Debug/test_periodic/26-all.csv',
#  '../vs_gol/Debug/test_periodic/27-all.csv',
#  '../vs_gol/Debug/test_periodic/28-all.csv',
#  '../vs_gol/Debug/test_periodic/29-all.csv',
#  '../vs_gol/Debug/test_periodic/30-all.csv',
#  '../vs_gol/Debug/test_periodic/31-all.csv',
#  '../vs_gol/Debug/test_periodic/32-all.csv',
#  '../vs_gol/Debug/test_periodic/33-all.csv',
#  '../vs_gol/Debug/test_periodic/34-all.csv',
#  '../vs_gol/Debug/test_periodic/35-all.csv',
#  '../vs_gol/Debug/test_periodic/36-all.csv',
#  '../vs_gol/Debug/test_periodic/37-all.csv',
#  '../vs_gol/Debug/test_periodic/38-all.csv',
#  '../vs_gol/Debug/test_periodic/39-all.csv',
#  '../vs_gol/Debug/test_periodic/40-all.csv',
#  '../vs_gol/Debug/test_periodic/41-all.csv',
#  '../vs_gol/Debug/test_periodic/42-all.csv',
#  '../vs_gol/Debug/test_periodic/43-all.csv',
#  '../vs_gol/Debug/test_periodic/44-all.csv',
#  '../vs_gol/Debug/test_periodic/45-all.csv',
#  '../vs_gol/Debug/test_periodic/46-all.csv',
#  '../vs_gol/Debug/test_periodic/47-all.csv',
#  '../vs_gol/Debug/test_periodic/48-all.csv',
#  '../vs_gol/Debug/test_periodic/49-all.csv',
#  '../vs_gol/Debug/test_periodic/50-all.csv',
#  '../vs_gol/Debug/test_periodic/51-all.csv',
#  '../vs_gol/Debug/test_periodic/52-all.csv',
#  '../vs_gol/Debug/test_periodic/53-all.csv',
#  '../vs_gol/Debug/test_periodic/54-all.csv',
#  '../vs_gol/Debug/test_periodic/55-all.csv',
#  '../vs_gol/Debug/test_periodic/56-all.csv',
#  '../vs_gol/Debug/test_periodic/57-all.csv',
#  '../vs_gol/Debug/test_periodic/58-all.csv',
#  '../vs_gol/Debug/test_periodic/59-all.csv',
#  '../vs_gol/Debug/test_periodic/60-all.csv',
#  '../vs_gol/Debug/test_periodic/61-all.csv',
#  '../vs_gol/Debug/test_periodic/62-all.csv',
#  '../vs_gol/Debug/test_periodic/63-all.csv',
#  '../vs_gol/Debug/test_periodic/64-all.csv',
#  '../vs_gol/Debug/test_periodic/65-all.csv',
#  '../vs_gol/Debug/test_periodic/66-all.csv',
#  '../vs_gol/Debug/test_periodic/67-all.csv',
#  '../vs_gol/Debug/test_periodic/68-all.csv',
#  '../vs_gol/Debug/test_periodic/69-all.csv',
#  '../vs_gol/Debug/test_periodic/70-all.csv',
#  '../vs_gol/Debug/test_periodic/71-all.csv',
#  '../vs_gol/Debug/test_periodic/72-all.csv',
#  '../vs_gol/Debug/test_periodic/73-all.csv',
#  '../vs_gol/Debug/test_periodic/74-all.csv',
#  '../vs_gol/Debug/test_periodic/75-all.csv',
#  '../vs_gol/Debug/test_periodic/76-all.csv',
#  '../vs_gol/Debug/test_periodic/77-all.csv',
#  '../vs_gol/Debug/test_periodic/78-all.csv',
#  '../vs_gol/Debug/test_periodic/79-all.csv',
#  '../vs_gol/Debug/test_periodic/80-all.csv',
#  '../vs_gol/Debug/test_periodic/81-all.csv',
#  '../vs_gol/Debug/test_periodic/82-all.csv',
#  '../vs_gol/Debug/test_periodic/83-all.csv',
#  '../vs_gol/Debug/test_periodic/84-all.csv',
#  '../vs_gol/Debug/test_periodic/85-all.csv',
#  '../vs_gol/Debug/test_periodic/86-all.csv',
#  '../vs_gol/Debug/test_periodic/87-all.csv',
#  '../vs_gol/Debug/test_periodic/88-all.csv',
#  '../vs_gol/Debug/test_periodic/89-all.csv',
#  '../vs_gol/Debug/test_periodic/90-all.csv',
#  '../vs_gol/Debug/test_periodic/91-all.csv',
#  '../vs_gol/Debug/test_periodic/92-all.csv',
#  '../vs_gol/Debug/test_periodic/93-all.csv',
#  '../vs_gol/Debug/test_periodic/94-all.csv',
#  '../vs_gol/Debug/test_periodic/95-all.csv',
#  '../vs_gol/Debug/test_periodic/96-all.csv',
#  '../vs_gol/Debug/test_periodic/97-all.csv',
#  '../vs_gol/Debug/test_periodic/98-all.csv',
#  '../vs_gol/Debug/test_periodic/99-all.csv',
#  '../vs_gol/Debug/test_periodic/100-all.csv']
# [(20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20)]

# %%
gol_ani = animate_imshow(results, 1, iter_start)
gol_ani.delay = 100
gol_ani.run(html=True)
#gol_ani.save(directory + node + "-" + iter_start + "-" iter_end + ".html")
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_img22845536c31644f7aafe74b1747f1bc8">
#     <br>
#     <input id="_anim_slider22845536c31644f7aafe74b1747f1bc8" type="range" style="width:350px"
#            name="points" min="0" max="1" step="1" value="0"
#            onchange="anim22845536c31644f7aafe74b1747f1bc8.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="anim22845536c31644f7aafe74b1747f1bc8.slower()"><i class="fa fa-minus"></i></button>
#     <button onclick="anim22845536c31644f7aafe74b1747f1bc8.first_frame()"><i class="fa fa-fast-backward">
#         </i></button>
#     <button onclick="anim22845536c31644f7aafe74b1747f1bc8.previous_frame()">
#         <i class="fa fa-step-backward"></i></button>
#     <button onclick="anim22845536c31644f7aafe74b1747f1bc8.reverse_animation()">
#         <i class="fa fa-play fa-flip-horizontal"></i></button>
#     <button onclick="anim22845536c31644f7aafe74b1747f1bc8.pause_animation()"><i class="fa fa-pause">
#         </i></button>
#     <button onclick="anim22845536c31644f7aafe74b1747f1bc8.play_animation()"><i class="fa fa-play"></i>
#         </button>
#     <button onclick="anim22845536c31644f7aafe74b1747f1bc8.next_frame()"><i class="fa fa-step-forward">
#         </i></button>
#     <button onclick="anim22845536c31644f7aafe74b1747f1bc8.last_frame()"><i class="fa fa-fast-forward">
#         </i></button>
#     <button onclick="anim22845536c31644f7aafe74b1747f1bc8.faster()"><i class="fa fa-plus"></i></button>
#   <form action="#n" name="_anim_loop_select22845536c31644f7aafe74b1747f1bc8" class="anim_control">
#     <input type="radio" name="state"
#            value="once" > Once </input>
#     <input type="radio" name="state"
#            value="loop" checked> Loop </input>
#     <input type="radio" name="state"
#            value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img22845536c31644f7aafe74b1747f1bc8";
#     var slider_id = "_anim_slider22845536c31644f7aafe74b1747f1bc8";
#     var loop_select_id = "_anim_loop_select22845536c31644f7aafe74b1747f1bc8";
#     var frames = new Array(0);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADl0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uIDIuMi4yLCBo\
# dHRwOi8vbWF0cGxvdGxpYi5vcmcvhp/UCwAAIABJREFUeJzt3XtYlHX+//HXwGhqiEkuBI7KIuQJ\
# kB+Kh9ZYq8VTG8VqGWtlYbFWbH3L1drdTra26p5yd+1nsWmR117SrlvhmiJp2q/MpKmlNt3L0JUE\
# PKV41hTh8/ujq/lGA2oc5p6PPh/X1XUx87nv4c00+vS+Z5hxGWOMAACwTIjTAwAA0BwEDABgJQIG\
# ALASAQMAWImAAQCsRMAAAFYiYAAAKxEwAICVCBgAwEoEDABgJQIGALASAQMAWImAAQCsRMAAAF