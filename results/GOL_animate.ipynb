# %%
import os
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import matplotlib.animation as an
from IPython.display import display, HTML

# %%
# animation class
class animate_imshow():
    def __init__(self, arrays, dt=1, t0=1):
        """
        Array is a list of 2d arrays or a 3d array with time on axis=0.
        Note in jupyter the animation needs to be done"
        """ 
        # setup data
        self.arr = arrays
        self.Nt = len(arrays)
        self.Nx = len(arrays[0])
        self.dt = dt
        self.t0 = t0

        # setup the figure
        self.fig = plt.figure(figsize=(6, 6))
        self.im = plt.imshow(arrays[0], animated=True, cmap='viridis')
        self.ax = plt.gca()
        self.text = self.ax.text(0.02*self.Nx, 0.04*self.Nx, 'Time: ' + str(t0), color='w')
        
        # settings
        self.delay = 10
        self.title = "title"
        self.xlabel = "xlabel"
        self.ylabel = "ylabel"

        # run the animation
    def run(self, html = False):
        self.ax.set(title=self.title, xlabel=self.xlabel, ylabel=self.ylabel)
        self.ani = an.FuncAnimation(self.fig, self.update, frames=range(self.Nt),
                                    interval=self.delay, blit=True)
        
        if html: # use this if in ipython/jupyter notebooks
            plt.close(self.fig)
            self.jshtml = self.ani.to_jshtml()
            display(HTML(self.jshtml))
    
    def save_html(self, filename = "output.html"):
        if not hasattr(self, 'jshtml'):
            self.jshtml = self.ani.to_jshtml()
        f = open(filename, 'w')
        f.write(self.jshtml)
        f.close()
            
    def update(self, f):
        self.im.set_array(self.arr[f])
        time = int(f * self.dt + self.t0)
        self.text.set_text('Time: %i' % time)
        return self.im, self.text

# %%
# what to load
directory = "../vs_gol/Debug/test_glider/"
node = "all"
iter_start = 0
iter_end = 100

# check directory is real
assert os.path.isdir(directory), "Given directory does not exist"

# generate all file names
files = [directory + str(i) + "-" + str(node) + ".csv" for i in range(iter_start, iter_end + 1)]
display(files)

# check all files exist
assert all([os.path.isfile(f) for f in files]), "One or more iteration files does not exist"

# load the data and check the dimensions match
results = [np.loadtxt(f, dtype=int, delimiter=',') for f in files]
display([r.shape for r in results])
assert all([results[0].shape == r.shape for r in results]), "Save files have incorrect dimensions"
#display(results)

# %%
gol_ani = animate_imshow(results, 1, iter_start)
gol_ani.delay = 100
gol_ani.run(html=True)
#gol_ani.save(directory + node + "-" + iter_start + "-" iter_end + ".html")
# Out:
# ['../vs_gol/Debug/test_glider/0-all.csv',
#  '../vs_gol/Debug/test_glider/1-all.csv',
#  '../vs_gol/Debug/test_glider/2-all.csv',
#  '../vs_gol/Debug/test_glider/3-all.csv',
#  '../vs_gol/Debug/test_glider/4-all.csv',
#  '../vs_gol/Debug/test_glider/5-all.csv',
#  '../vs_gol/Debug/test_glider/6-all.csv',
#  '../vs_gol/Debug/test_glider/7-all.csv',
#  '../vs_gol/Debug/test_glider/8-all.csv',
#  '../vs_gol/Debug/test_glider/9-all.csv',
#  '../vs_gol/Debug/test_glider/10-all.csv',
#  '../vs_gol/Debug/test_glider/11-all.csv',
#  '../vs_gol/Debug/test_glider/12-all.csv',
#  '../vs_gol/Debug/test_glider/13-all.csv',
#  '../vs_gol/Debug/test_glider/14-all.csv',
#  '../vs_gol/Debug/test_glider/15-all.csv',
#  '../vs_gol/Debug/test_glider/16-all.csv',
#  '../vs_gol/Debug/test_glider/17-all.csv',
#  '../vs_gol/Debug/test_glider/18-all.csv',
#  '../vs_gol/Debug/test_glider/19-all.csv',
#  '../vs_gol/Debug/test_glider/20-all.csv',
#  '../vs_gol/Debug/test_glider/21-all.csv',
#  '../vs_gol/Debug/test_glider/22-all.csv',
#  '../vs_gol/Debug/test_glider/23-all.csv',
#  '../vs_gol/Debug/test_glider/24-all.csv',
#  '../vs_gol/Debug/test_glider/25-all.csv',
#  '../vs_gol/Debug/test_glider/26-all.csv',
#  '../vs_gol/Debug/test_glider/27-all.csv',
#  '../vs_gol/Debug/test_glider/28-all.csv',
#  '../vs_gol/Debug/test_glider/29-all.csv',
#  '../vs_gol/Debug/test_glider/30-all.csv',
#  '../vs_gol/Debug/test_glider/31-all.csv',
#  '../vs_gol/Debug/test_glider/32-all.csv',
#  '../vs_gol/Debug/test_glider/33-all.csv',
#  '../vs_gol/Debug/test_glider/34-all.csv',
#  '../vs_gol/Debug/test_glider/35-all.csv',
#  '../vs_gol/Debug/test_glider/36-all.csv',
#  '../vs_gol/Debug/test_glider/37-all.csv',
#  '../vs_gol/Debug/test_glider/38-all.csv',
#  '../vs_gol/Debug/test_glider/39-all.csv',
#  '../vs_gol/Debug/test_glider/40-all.csv',
#  '../vs_gol/Debug/test_glider/41-all.csv',
#  '../vs_gol/Debug/test_glider/42-all.csv',
#  '../vs_gol/Debug/test_glider/43-all.csv',
#  '../vs_gol/Debug/test_glider/44-all.csv',
#  '../vs_gol/Debug/test_glider/45-all.csv',
#  '../vs_gol/Debug/test_glider/46-all.csv',
#  '../vs_gol/Debug/test_glider/47-all.csv',
#  '../vs_gol/Debug/test_glider/48-all.csv',
#  '../vs_gol/Debug/test_glider/49-all.csv',
#  '../vs_gol/Debug/test_glider/50-all.csv',
#  '../vs_gol/Debug/test_glider/51-all.csv',
#  '../vs_gol/Debug/test_glider/52-all.csv',
#  '../vs_gol/Debug/test_glider/53-all.csv',
#  '../vs_gol/Debug/test_glider/54-all.csv',
#  '../vs_gol/Debug/test_glider/55-all.csv',
#  '../vs_gol/Debug/test_glider/56-all.csv',
#  '../vs_gol/Debug/test_glider/57-all.csv',
#  '../vs_gol/Debug/test_glider/58-all.csv',
#  '../vs_gol/Debug/test_glider/59-all.csv',
#  '../vs_gol/Debug/test_glider/60-all.csv',
#  '../vs_gol/Debug/test_glider/61-all.csv',
#  '../vs_gol/Debug/test_glider/62-all.csv',
#  '../vs_gol/Debug/test_glider/63-all.csv',
#  '../vs_gol/Debug/test_glider/64-all.csv',
#  '../vs_gol/Debug/test_glider/65-all.csv',
#  '../vs_gol/Debug/test_glider/66-all.csv',
#  '../vs_gol/Debug/test_glider/67-all.csv',
#  '../vs_gol/Debug/test_glider/68-all.csv',
#  '../vs_gol/Debug/test_glider/69-all.csv',
#  '../vs_gol/Debug/test_glider/70-all.csv',
#  '../vs_gol/Debug/test_glider/71-all.csv',
#  '../vs_gol/Debug/test_glider/72-all.csv',
#  '../vs_gol/Debug/test_glider/73-all.csv',
#  '../vs_gol/Debug/test_glider/74-all.csv',
#  '../vs_gol/Debug/test_glider/75-all.csv',
#  '../vs_gol/Debug/test_glider/76-all.csv',
#  '../vs_gol/Debug/test_glider/77-all.csv',
#  '../vs_gol/Debug/test_glider/78-all.csv',
#  '../vs_gol/Debug/test_glider/79-all.csv',
#  '../vs_gol/Debug/test_glider/80-all.csv',
#  '../vs_gol/Debug/test_glider/81-all.csv',
#  '../vs_gol/Debug/test_glider/82-all.csv',
#  '../vs_gol/Debug/test_glider/83-all.csv',
#  '../vs_gol/Debug/test_glider/84-all.csv',
#  '../vs_gol/Debug/test_glider/85-all.csv',
#  '../vs_gol/Debug/test_glider/86-all.csv',
#  '../vs_gol/Debug/test_glider/87-all.csv',
#  '../vs_gol/Debug/test_glider/88-all.csv',
#  '../vs_gol/Debug/test_glider/89-all.csv',
#  '../vs_gol/Debug/test_glider/90-all.csv',
#  '../vs_gol/Debug/test_glider/91-all.csv',
#  '../vs_gol/Debug/test_glider/92-all.csv',
#  '../vs_gol/Debug/test_glider/93-all.csv',
#  '../vs_gol/Debug/test_glider/94-all.csv',
#  '../vs_gol/Debug/test_glider/95-all.csv',
#  '../vs_gol/Debug/test_glider/96-all.csv',
#  '../vs_gol/Debug/test_glider/97-all.csv',
#  '../vs_gol/Debug/test_glider/98-all.csv',
#  '../vs_gol/Debug/test_glider/99-all.csv',
#  '../vs_gol/Debug/test_glider/100-all.csv']
# [(20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20),
#  (20, 20)]
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/
# css/font-awesome.min.css">
# <script language="javascript">
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     document.getElementById(this.slider_id).max = this.frames.length - 1;
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <div class="animation" align="center">
#     <img id="_anim_img6fe8ee641c9d4e60aaff8062e46e7f45">
#     <br>
#     <input id="_anim_slider6fe8ee641c9d4e60aaff8062e46e7f45" type="range" style="width:350px"
#            name="points" min="0" max="1" step="1" value="0"
#            onchange="anim6fe8ee641c9d4e60aaff8062e46e7f45.set_frame(parseInt(this.value));"></input>
#     <br>
#     <button onclick="anim6fe8ee641c9d4e60aaff8062e46e7f45.slower()"><i class="fa fa-minus"></i></button>
#     <button onclick="anim6fe8ee641c9d4e60aaff8062e46e7f45.first_frame()"><i class="fa fa-fast-backward">
#         </i></button>
#     <button onclick="anim6fe8ee641c9d4e60aaff8062e46e7f45.previous_frame()">
#         <i class="fa fa-step-backward"></i></button>
#     <button onclick="anim6fe8ee641c9d4e60aaff8062e46e7f45.reverse_animation()">
#         <i class="fa fa-play fa-flip-horizontal"></i></button>
#     <button onclick="anim6fe8ee641c9d4e60aaff8062e46e7f45.pause_animation()"><i class="fa fa-pause">
#         </i></button>
#     <button onclick="anim6fe8ee641c9d4e60aaff8062e46e7f45.play_animation()"><i class="fa fa-play"></i>
#         </button>
#     <button onclick="anim6fe8ee641c9d4e60aaff8062e46e7f45.next_frame()"><i class="fa fa-step-forward">
#         </i></button>
#     <button onclick="anim6fe8ee641c9d4e60aaff8062e46e7f45.last_frame()"><i class="fa fa-fast-forward">
#         </i></button>
#     <button onclick="anim6fe8ee641c9d4e60aaff8062e46e7f45.faster()"><i class="fa fa-plus"></i></button>
#   <form action="#n" name="_anim_loop_select6fe8ee641c9d4e60aaff8062e46e7f45" class="anim_control">
#     <input type="radio" name="state"
#            value="once" > Once </input>
#     <input type="radio" name="state"
#            value="loop" checked> Loop </input>
#     <input type="radio" name="state"
#            value="reflect" > Reflect </input>
#   </form>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img6fe8ee641c9d4e60aaff8062e46e7f45";
#     var slider_id = "_anim_slider6fe8ee641c9d4e60aaff8062e46e7f45";
#     var loop_select_id = "_anim_loop_select6fe8ee641c9d4e60aaff8062e46e7f45";
#     var frames = new Array(0);
#
#   frames[0] = "...\
# AAALEgAACxIB0t1+/AAAADl0RVh0U29mdHdhcmUAbWF0cGxvdGxpYiB2ZXJzaW9uIDIuMi4yLCBo\
# dHRwOi8vbWF0cGxvdGxpYi5vcmcvhp/UCwAAIABJREFUeJzt3XtYlHX+//HXwGhqiEkuBI7KIuQJ\
# kB+Kh9ZYq8VTG8VqGWtlYbFWbH3L1drdTra26p5yd+1nsWmR117SrlvhmiJp2q/MpKmlNt3L0JUE\
# PKV41hTh8/ujq/lGA2oc5p6PPh/X1XUx87nv4c00+vS+Z5hxGWOMAACwTIjTAwAA0BwEDABgJQIG\
# ALASAQMAWImAAQCsRMAAAFYiYAAAKxEwAICVCBgAwEoEDABgJQIGALASAQMAWImAAQCsRMAAAFYi\
# YAAAKxEwAICVCBgAwEoEDABgJQIGALASAQMAWImAAQCsRMAAAFYiYAAAKxEwAICVCBgAwEoED